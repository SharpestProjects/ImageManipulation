# %%
import imgen as ig
import os
import cv2 as cv
import numpy as np
# import pandas as pd
import random
import matplotlib.pyplot as plt
# %matplotlib inline

print(cv.__version__)
# Out:
# 4.1.2

# %%
path = 'logos/'
raw_images = ig.load_images(path)

clean_imgs = ig.clean_images(raw_images,cv.COLOR_BGR2RGB)

img_list = clean_imgs.copy()

instruct = np.random.randint(2, size=(1, 4))
print(instruct)

for i in range(len(img_list)):
    
    plt.figure()
    plt.imshow(img_list[i])
    plt.show()

    img_list[i] = ig.rotate_image(img_list[i])
    
    img_list[i] = ig.draw_random_line(img_list[i])
    
    img_list[i] = ig.draw_random_circle(img_list[i])
    
    img_list[i] = ig.draw_random_filled_polygon(img_list[i])

    
    plt.figure()
    plt.imshow(img_list[i])
    plt.show()

# %%
from random import shuffle
#incomplete code for master function to generate all images
def generate_images(img, instruct):
    
#     print(shuffle, rotate, line, circle, polygon)
    rotate_image,draw_random_line,draw_random_circle,draw_random_filled_polygon = str(instruct).split()
    
    func_list = [rotate_image,draw_random_line,draw_random_circle,draw_random_filled_polygon]    
    print("ordered: ",func_list)

    random.shuffle(func_list)
    print("random: ",func_list)
    
    for i in func_list:
        i()
#     rotate_image(img,degrees,shrinkage)
#     draw_random_line(img, line_color, line_thickness)
#     draw_random_circle(img, circle_radius, circle_color, thickness)
#     draw_random_filled_polygon(img,num_points,poly_color)
    
    return img_list

# %%
instruct = np.random.randint(2, size=(1, 4))
print(type(instruct))
print(instruct)

mask = instruct>0
print(mask)
func_list = [ig.rotate_image,ig.draw_random_line,ig.draw_random_circle,ig.draw_random_filled_polygon]

print(func_list[mask])



# rotate_image,draw_random_line,draw_random_circle,draw_random_filled_polygon = instruct.split()

# print(rotate_image,draw_random_line,draw_random_circle,draw_random_filled_polygon)
# Out:
# <class 'numpy.ndarray'>
# [[1 1 1 1]]
# [[ True  True  True  True]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-b898256bb146> in <module>
#       7 func_list = [ig.rotate_image,ig.draw_random_line,ig.draw_random_circle,ig.draw_random_filled_polygon]
#       8
# ----> 9 print(func_list[instruct])
#      10
#      11
#
# TypeError: only integer scalar arrays can be converted to a scalar index
